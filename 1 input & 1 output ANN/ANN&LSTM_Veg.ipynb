# %%
#https://github.com/susanli2016/Machine-Learning-with-Python/blob/master/Time%20Series%20ANN%20%26%20LSTM%20VIX.ipynb
#https://towardsdatascience.com/an-introduction-on-time-series-forecasting-with-simple-neura-networks-lstm-f788390915b
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.optimizers import Adam
from keras.layers import LSTM
import numpy

# %%
df = pd.read_excel('/content/veg dates.xlsx')

# %%
print(df.head())
# Out:
#         Date  Average of NDVI Avg. Number of pixel
# 0 2001-01-01                               9418.25
# 1 2001-02-01                              12998.90
# 2 2001-03-01                              12748.55
# 3 2001-04-01                              13755.60
# 4 2001-05-01                              15193.80

# %%
#df.drop(['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10'], axis=1, inplace=True)

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df = df.set_index(['Date'], drop=True)

# %%
print(df.head(15))
# Out:
# Date
# 2001-01-01     9418.25
# 2001-02-01    12998.90
# 2001-03-01    12748.55
# 2001-04-01    13755.60
# 2001-05-01    15193.80
# 2001-06-01    14378.25
# 2001-07-01    15706.15
# 2001-08-01    15859.10
# 2001-09-01    16652.70
# 2001-10-01    15737.75
# 2001-11-01    14600.60
# 2001-12-01    13657.45
# 2002-01-01    10473.96
# 2002-02-01    11311.00
# 2002-03-01    13008.30
# Name: Average of NDVI Avg. Number of pixel, dtype: float64

# %%
# df = df.sort_index()
plt.figure(figsize=(10, 6))
df['Average of NDVI Avg. Number of pixel'].plot();

# %%
split_date = pd.Timestamp('2012-12-01')

# %%
df =  df['Average of NDVI Avg. Number of pixel']
train = df.loc[:split_date]
test = df.loc[split_date:]
plt.figure(figsize=(10, 6))
ax = train.plot()
test.plot(ax=ax)
plt.legend(['train', 'test']);

# %%
scaler = MinMaxScaler(feature_range=(-1, 1))
train_sc = scaler.fit_transform(train.values.reshape(-1, 1))
test_sc = scaler.transform(test.values.reshape(-1, 1))

# %%
X_train = train_sc[:-1]
y_train = train_sc[1:]

X_test = test_sc[:-1]
y_test = test_sc[1:]

# %% [markdown]
# ## **NN**

# %%
nn_model = Sequential()
nn_model.add(Dense(8, input_dim=1, activation='relu'))
nn_model.add(Dense(1))
nn_model.compile(loss='mean_squared_error', optimizer='adam')
early_stop = EarlyStopping(monitor='loss', patience=2, verbose=1)
history = nn_model.fit(X_train, y_train, epochs=100, batch_size=24, verbose=1, callbacks=[early_stop], shuffle=False)
# Out:
# Epoch 1/100
# 143/143 [==============================] - 0s 3ms/step - loss: 0.3977
# Epoch 2/100
# 143/143 [==============================] - 0s 56us/step - loss: 0.3664
# Epoch 3/100
# 143/143 [==============================] - 0s 62us/step - loss: 0.3359
# Epoch 4/100
# 143/143 [==============================] - 0s 52us/step - loss: 0.3078
# Epoch 5/100
# 143/143 [==============================] - 0s 57us/step - loss: 0.2820
# Epoch 6/100
# 143/143 [==============================] - 0s 56us/step - loss: 0.2587
# Epoch 7/100
# 143/143 [==============================] - 0s 57us/step - loss: 0.2377
# Epoch 8/100
# 143/143 [==============================] - 0s 67us/step - loss: 0.2189
# Epoch 9/100
# 143/143 [==============================] - 0s 71us/step - loss: 0
100
# 143/143 [==============================] - 0s 69us/step - loss: 0.0685
# Epoch 90/100
# 143/143 [==============================] - 0s 75us/step - loss: 0.0685
# Epoch 91/100
# 143/143 [==============================] - 0s 65us/step - loss: 0.0685
# Epoch 92/100
# 143/143 [==============================] - 0s 71us/step - loss: 0.0685
# Epoch 93/100
# 143/143 [==============================] - 0s 82us/step - loss: 0.0685
# Epoch 94/100
# 143/143 [==============================] - 0s 65us/step - loss: 0.0685
# Epoch 95/100
# 143/143 [==============================] - 0s 69us/step - loss: 0.0685
# Epoch 96/100
# 143/143 [==============================] - 0s 102us/step - loss: 0.0685
# Epoch 97/100
# 143/143 [==============================] - 0s 70us/step - loss: 0.0685
# Epoch 98/100
# 143/143 [==============================] - 0s 70us/step - loss: 0.0685
# Epoch 99/100
# 143/143 [==============================] - 0s 59us/step - loss: 0.0685
# Epoch 100/100
# 143/143 [==============================] - 0s 69us/step - loss: 0.0685

# %%
y_pred_test_nn = nn_model.predict(X_test)
y_train_pred_nn = nn_model.predict(X_train)
print("The R2 score on the Train set is:\t{:0.3f}".format(r2_score(y_train, y_train_pred_nn)))
print("The R2 score on the Test set is:\t{:0.3f}".format(r2_score(y_test, y_pred_test_nn)))
# Out:
# The R2 score on the Train set is:	0.546
# The R2 score on the Test set is:	0.404

# %% [markdown]
# ## **LSTM**

# %%
train_sc_df = pd.DataFrame(train_sc, columns=['Y'], index=train.index)
test_sc_df = pd.DataFrame(test_sc, columns=['Y'], index=test.index)

for s in range(1,2):
    train_sc_df['X_{}'.format(s)] = train_sc_df['Y'].shift(s)
    test_sc_df['X_{}'.format(s)] = test_sc_df['Y'].shift(s)

X_train = train_sc_df.dropna().drop('Y', axis=1)
y_train = train_sc_df.dropna().drop('X_1', axis=1)

X_test = test_sc_df.dropna().drop('Y', axis=1)
y_test = test_sc_df.dropna().drop('X_1', axis=1)

X_train = X_train.as_matrix()
y_train = y_train.as_matrix()

X_test = X_test.as_matrix()
y_test = y_test.as_matrix()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:18: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %%
X_train_lmse = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test_lmse = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

print('Train shape: ', X_train_lmse.shape)
print('Test shape: ', X_test_lmse.shape)
# Out:
# Train shape:  (143, 1, 1)
# Test shape:  (60, 1, 1)

# %%
lstm_model = Sequential()
lstm_model.add(LSTM(50, input_shape=(1, X_train_lmse.shape[1]), activation='relu', kernel_initializer='lecun_uniform', return_sequences=False))
lstm_model.add(Dense(1))
lstm_model.compile(loss='mean_squared_error', optimizer='adam')
early_stop = EarlyStopping(monitor='loss', patience=2, verbose=1)
history_lstm_model = lstm_model.fit(X_train_lmse, y_train, epochs=100, batch_size=24, verbose=2, shuffle=False, callbacks=[early_stop])
# Out:
# Epoch 1/100
#  - 1s - loss: 0.1099
# Epoch 2/100
#  - 0s - loss: 0.0989
# Epoch 3/100
#  - 0s - loss: 0.0895
# Epoch 4/100
#  - 0s - loss: 0.0822
# Epoch 5/100
#  - 0s - loss: 0.0770
# Epoch 6/100
#  - 0s - loss: 0.0735
# Epoch 7/100
#  - 0s - loss: 0.0715
# Epoch 8/100
#  - 0s - loss: 0.0703
# Epoch 9/100
#  - 0s - loss: 0.0697
# Epoch 10/100
#  - 0s - loss: 0.0693
# Epoch 11/100
#  - 0s - loss: 0.0691
# Epoch 12/100
#  - 0s - loss: 0.0689
# Epoch 13/100
#  - 0s - loss: 0.0688
# Epoch 14/100
#  - 0s - loss: 0.0687
# Epoch 15/100
#  - 0s - loss: 0.0686
# Epoch 16/100
#  - 0s - loss: 0.0685
# Epoch 17/100
#  - 0s - loss: 0.0685
# Epoch 18/100
#  - 0s - loss: 0.0684
# Epoch 19/100
#  - 0s - loss: 0.0684
# Epoch 20/100
#  - 0s - loss: 0.0684
# Epoch 21/100
#  - 0s - loss: 0.0683
# Epoch 22/100
#  - 0s - loss: 0.0683
# Epoch 23/100
#  - 0s - loss: 0.0683
# Epoch 24/100
#  - 0s - loss: 0.0683
# Epoch 25/100
#  - 0s - loss: 0.0683
# Epoch 26/100
#  - 0s - loss: 0.0682
# Epoch 27/100
#  - 0s - loss: 0.0682
# Epoch 28/100
#  - 0s - loss: 0.0682
# Epoch 29/100
#  - 0s - loss: 0.0682
# Epoch 30/100
#  - 0s - loss: 0.0682
# Epoch 31/100
#  - 0s - loss: 0.0681
# Epoch 32/100
#  - 0s - loss: 0.0681
# Epoch 33/100
#  - 0s - loss: 0.0681
# Epoch 34/100
#  - 0s - loss: 0.0681
# Epoch 35/100
#  - 0s - loss: 0.0681
# Epoch 36/100
#  - 0s - loss: 0.0681
# Epoch 37/100
#  - 0s - loss: 0.0681
# Epoch 38/100
#  - 0s - loss: 0.0680
# Epoch 39/100
#  - 0s - loss: 0.0680
# Epoch 40/100
#  - 0s - loss: 0.0680
# Epoch 41/100
#  - 0s - loss: 0.0680
# Epoch 42/100
#  - 0s - loss: 0.0680
# Epoch 43/100
#  - 0s - loss: 0.0680
# Epoch 44/100
#  - 0s - loss: 0.0680
# Epoch 45/100
#  - 0s - loss: 0.0680
# Epoch 46/100
#  - 0s - loss: 0.0680
# Epoch 47/100
#  - 0s - loss: 0.0680
# Epoch 48/100
#  - 0s - loss: 0.0679
# Epoch 49/100
#  - 0s - loss: 0.0679
# Epoch 50/100
#  - 0s - loss: 0.0679
# Epoch 51/100
#  - 0s - loss: 0.0679
# Epoch 52/100
#  - 0s - loss: 0.0679
# Epoch 53/100
#  - 0s - loss: 0.0679
# Epoch 54/100
#  - 0s - loss: 0.0679
# Epoch 55/100
#  - 0s - loss: 0.0679
# Epoch 56/100
#  - 0s - loss: 0.0679
# Epoch 57/100
#  - 0s - loss: 0.0679
# Epoch 58/100
#  - 0s - loss: 0.0679
# Epoch 59/100
#  - 0s - loss: 0.0678
# Epoch 60/100
#  - 0s - loss: 0.0678
# Epoch 61/100
#  - 0s - loss: 0.0678
# Epoch 62/100
#  - 0s - loss: 0.0678
# Epoch 63/100
#  - 0s - loss: 0.0678
# Epoch 64/100
#  - 0s - loss: 0.0678
# Epoch 65/100
#  - 0s - loss: 0.0678
# Epoch 66/100
#  - 0s - loss: 0.0678
# Epoch 67/100
#  - 0s - loss: 0.0678
# Epoch 68/100
#  - 0s - loss: 0.0678
# Epoch 69/100
#  - 0s - loss: 0.0678
# Epoch 70/100
#  - 0s - loss: 0.0678
# Epoch 71/100
#  - 0s - loss: 0.0678
# Epoch 72/100
#  - 0s - loss: 0.0677
# Epoch 73/100
#  - 0s - loss: 0.0677
# Epoch 74/100
#  - 0s - loss: 0.0677
# Epoch 75/100
#  - 0s - loss: 0.0677
# Epoch 76/100
#  - 0s - loss: 0.0677
# Epoch 77/100
#  - 0s - loss: 0.0677
# Epoch 78/100
#  - 0s - loss: 0.0677
# Epoch 79/100
#  - 0s - loss: 0.0677
# Epoch 80/100
#  - 0s - loss: 0.0677
# Epoch 81/100
#  - 0s - loss: 0.0677
# Epoch 82/100
#  - 0s - loss: 0.0677
# Epoch 83/100
#  - 0s - loss: 0.0677
# Epoch 84/100
#  - 0s - loss: 0.0677
# Epoch 85/100
#  - 0s - loss: 0.0676
# Epoch 86/100
#  - 0s - loss: 0.0676
# Epoch 87/100
#  - 0s - loss: 0.0676
# Epoch 88/100
#  - 0s - loss: 0.0676
# Epoch 89/100
#  - 0s - loss: 0.0676
# Epoch 90/100
#  - 0s - loss: 0.0676
# Epoch 91/100
#  - 0s - loss: 0.0676
# Epoch 92/100
#  - 0s - loss: 0.0676
# Epoch 93/100
#  - 0s - loss: 0.0676
# Epoch 94/100
#  - 0s - loss: 0.0676
# Epoch 95/100
#  - 0s - loss: 0.0676
# Epoch 96/100
#  - 0s - loss: 0.0676
# Epoch 97/100
#  - 0s - loss: 0.0676
# Epoch 98/100
#  - 0s - loss: 0.0675
# Epoch 99/100
#  - 0s - loss: 0.0675
# Epoch 100/100
#  - 0s - loss: 0.0675

# %%
y_pred_test_lstm = lstm_model.predict(X_test_lmse)
y_train_pred_lstm = lstm_model.predict(X_train_lmse)
print("The R2 score on the Train set is:\t{:0.3f}".format(r2_score(y_train, y_train_pred_lstm)))
print("The R2 score on the Test set is:\t{:0.3f}".format(r2_score(y_test, y_pred_test_lstm)))
# Out:
# The R2 score on the Train set is:	0.552
# The R2 score on the Test set is:	0.407

# %%
nn_test_mse = nn_model.evaluate(X_test, y_test, batch_size=1)
lstm_test_mse = lstm_model.evaluate(X_test_lmse, y_test, batch_size=1)
print('NN: %f'%nn_test_mse)
print('LSTM: %f'%lstm_test_mse)
# Out:
# 60/60 [==============================] - 0s 632us/step
# 60/60 [==============================] - 0s 7ms/step
# NN: 0.108120
# LSTM: 0.107522

# %%
nn_y_pred_test = nn_model.predict(X_test)
lstm_y_pred_test = lstm_model.predict(X_test_lmse)

# %%
plt.figure(figsize=(10, 6))
plt.plot(y_test, label='True')
plt.plot(y_pred_test_nn, label='NN')
plt.title("ANN's Prediction")
plt.xlabel('Observation')
plt.ylabel('Average of Avg. Temperature in Kelvin')
plt.legend()
plt.show();

# %%
plt.figure(figsize=(10, 6))
plt.plot(y_test, label='True')
plt.plot(y_pred_test_lstm, label='LSTM')
plt.title("LSTM's Prediction")
plt.xlabel('Observation')
plt.ylabel('Average of Avg. Temperature in Kelvin')
plt.legend()
plt.show();
